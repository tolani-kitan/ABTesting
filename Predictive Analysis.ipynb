# %%
import sqlite3 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
soccerStats = pd.read_excel(r"C:\Users\User\Downloads\Soccer Data.xlsx")

# %%
soccerStats.head(5)
# Out:
#            league  teams_no       date       home_team     away_team  \
# 0  France-Ligue 2        20 2016-01-08         Ajaccio      Le Havre
# 1  France-Ligue 2        20 2016-01-08         Auxerre  Valenciennes
# 2  France-Ligue 2        20 2016-01-08  Bourg Peronnas       Creteil
# 3  France-Ligue 2        20 2016-01-08         Chamois         Dijon
# 4  France-Ligue 2        20 2016-01-08        Clermont         Evian
#
#    home_odd  draw_odd  away_odd  h_played  a_played  ...  a_final  h_half  \
# 0      2.63      2.97      3.24        19        19  ...      1.0     NaN
# 1      1.98      3.25      4.69        19        19  ...      1.0     NaN
# 2      2.00      3.52      4.14        19        19  ...      1.0     NaN
# 3      2.82      3.06      2.91        19        19  ...      2.0     NaN
# 4      2.10      3.21      4.20        19        19  ...      1.0     NaN
#
#    a_half  BTS  H1H  A1H  H2H  A2H  Unnamed: 79  Unnamed: 80
# ...
